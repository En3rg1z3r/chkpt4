# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
df= pd.read_csv("kc_house_data.csv")
#FIRST LOOK AT THE DATA
print(df.shape)
print(df.dtypes)
df.describe()
df.head()
# Out:
# (21613, 21)
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# ...

# %%
#PLOT
plt.boxplot(df.price)
sns.displot(df.price)
#high positive skewness
df.price = np.log(df.price) 
sns.displot(df.price)

# %%
#Data-Preprocessing
# days away from 2010/01/01, making the date useless
df["from2013"] = df.date.map(lambda dt: (pd.to_datetime(dt, yearfirst=True)-pd.to_datetime("20130101T000000")).days)
print(df)

#feature selection
#id and zipcode are useless
print(df[df.waterfront==0].shape) #waterfront column is useless
print(df[df.yr_renovated==0].shape) #yr_renovated is useless
print(df[df.view==0].shape) #view is useless too
print(df[df.sqft_basement==0].shape) #this must be kept, 8000~ houses have a basement
df.drop(["date", "zipcode", "waterfront", "yr_renovated","view","id"], axis=1, inplace=True)
df
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  12.309982         3       1.00
# 1      6414100192  20141209T000000  13.195614         3       2.25
# 2      5631500400  20150225T000000  12.100712         2       1.00
# 3      2487200875  20141209T000000  13.311329         4       3.00
# 4      1954400510  20150218T000000  13.142166         3       2.00
# ...           ...              ...        ...       ...        ...
# 21608   263000018  20140521T000000  12.793859         3       2.50
# 21609  6600060120  20150223T000000  12.899220         4       2.50
# 21610  1523300141  20140623T000000  12.904459         2       0.75
# 21611   291310100  20150116T000000  12.899220         3       2.50
# 21612  1523300157  20141015T000000  12.691580         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 0             1180      5650     1.0           0     0  ...        1180
# ...

# %%
plt.figure(figsize=(16, 6))
hm= sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True)
hm.set_title('Correlation Heatmap', fontdict={'fontsize':15}, pad=20)
# nearly strong positive corr(and > 0.50) between :
# price & bathrooms
# price & sqft_above
# price & grade
# price & sqft_living
# price & sqft_living15
#these are the main features for the price prediction 

#weak corr : 
# price & bedrooms
# price & lat (probably the nearer to some important places, the higher the price gets )
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
training_data, testing_data = train_test_split(df, test_size=0.2, random_state=25)

# %%
#linear reg : 
X = training_data[["sqft_living"]]
reg = LinearRegression().fit(X, training_data.price)
print(reg.score(X, training_data.price))

pred= reg.predict(testing_data[["sqft_living"]])
print("MSE : ", metrics.mean_squared_error(testing_data.price, pred))
print("R squared : ", metrics.r2_score(testing_data.price, pred))

Y = reg.coef_* df.sqft_living + reg.intercept_
plt.scatter(df.sqft_living, df.price)
plt.plot(df.sqft_living,Y, 'r')
# Out:
# 0.4828863015855086
# MSE :  0.14651449741340314
# R squared :  0.48584862488608227

# %%
from sklearn.preprocessing import PolynomialFeatures 
x= df[["grade"]]
y= df["price"]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=40)  #splitting data
lg=LinearRegression()
poly=PolynomialFeatures(degree=2)

x_train_fit = poly.fit_transform(x_train) #transforming our input data
lg.fit(x_train_fit, y_train)
x_test_ = poly.fit_transform(x_test)
predicted = lg.predict(x_test_)

print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
# Out:
# MSE:  0.13895796207856714
# R squared:  0.493666020282842

# %%
#multi linear reg
X = training_data[["grade","sqft_living","sqft_above", "bathrooms"]] 
reg = LinearRegression().fit(X, training_data.price)
print(reg.score(X,  training_data.price))

pred= reg.predict(testing_data[["grade","sqft_living", "sqft_above", "bathrooms"]])
print("MSE : ", metrics.mean_squared_error(testing_data.price, pred))
print("R squared : ", metrics.r2_score(testing_data.price, pred))
# Out:
# 0.562287136438872
# MSE :  0.12158939129428081
# R squared :  0.5733162667389405

# %%
#Multi reg is the best among them because its R is the highest
